# %% [markdown]
# # Jacket Images

# %%
import os
from glob import glob
import json
from PIL import Image

with open("../environment.json", "r") as f:
    env = json.load(f)

image_pathes = glob(os.path.join(env["DATASET_PATH"], "spotify_jackets", "**", "*.jpg"), recursive=True)
image_pathes[:3]
# Out:
# ['/data1/meta_midi_dataset/spotify_jackets/5/n/3/5n3es2C6R47r4WGfmYL9vZ.jpg',
#  '/data1/meta_midi_dataset/spotify_jackets/5/n/m/5nmX8TvysfndL9ld0IEqbU.jpg',
#  '/data1/meta_midi_dataset/spotify_jackets/5/n/E/5nEsuVhNXplVlzzYZhajwc.jpg']

# %%
import matplotlib.pyplot as plt

im = Image.open(image_pathes[2])
plt.imshow(im, cmap='Greys_r')
